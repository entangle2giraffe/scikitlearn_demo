# %%
#Import dependencies
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
#Read the .csv file
df = pd.read_csv("UNdata_Export_20181006_090917280.csv")

#View the sample of table
df.head()
# Out:
#              OID Country_or_Area  Year             Description Magnitude  \
# 0  91491F..ZF...         ALBANIA  2007  GOVERNMENT CONSUMPTION      LEKS
# 1  91491F..ZF...         ALBANIA  2006  GOVERNMENT CONSUMPTION      LEKS
# 2  91491F..ZF...         ALBANIA  2005  GOVERNMENT CONSUMPTION      LEKS
# 3  91491F..ZF...         ALBANIA  2004  GOVERNMENT CONSUMPTION      LEKS
# 4  91491F..ZF...         ALBANIA  2003  GOVERNMENT CONSUMPTION      LEKS
#
#           Value
# 0  9.835170e+10
# 1  8.941120e+10
# 2  8.850800e+10
# 3  8.248380e+10
# 4  7.558540e+10

# %%
#Set of Country_or_Area
country_row = df["Country_or_Area"]
country_set = set(country)
print(f"The numbers of row: {len(country_row)}.") 
print(f"The numbers of country: {len(country_set)}." )
print(country_set)
# Out:
# The numbers of row: 6879.
# The numbers of country: 167.
# ...

# %%
#Set of Year
print(set(df["Year"]))
# Out:
# {1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010}

# %%
#Fiji DataFrame only
condition = df["Country_or_Area"] == "FIJI"
fiji = df[condition]
fiji
# Out:
#                 OID Country_or_Area  Year                     Description  \
# 2103  81991F..ZF...            FIJI  2005  GOVERNMENT CONSUMPTION EXPEND.
# 2104  81991F..ZF...            FIJI  2004  GOVERNMENT CONSUMPTION EXPEND.
# 2105  81991F..ZF...            FIJI  2003  GOVERNMENT CONSUMPTION EXPEND.
# 2106  81991F..ZF...            FIJI  2002  GOVERNMENT CONSUMPTION EXPEND.
# 2107  81991F..ZF...            FIJI  2001  GOVERNMENT CONSUMPTION EXPEND.
# 2108  81991F..ZF...            FIJI  2000  GOVERNMENT CONSUMPTION EXPEND.
# 2109  81991F..ZF...            FIJI  1999  GOVERNMENT CONSUMPTION EXPEND.
# 2110  81991F..ZF...            FIJI  1998  GOVERNMENT CONSUMPTION EXPEND.
# 2111  81991F..ZF...            FIJI  1997  GOVERNMENT CONSUMPTION EXPEND.
# 2112  81991F..ZF...            FIJI  1996  GOVERNMENT CONSUMPTION EXPEND.
# 2113  81991F..ZF...            FIJI  1995  GOVERNMENT CONSUMPTION EXPEND.
# 2114  81991F..ZF...            FIJI  1994  GOVERNMENT CONSUMPTION EXPEND.
# ...

# %%
#Select only nessecary features
cdf = fiji[["Year", "Value"]]

# %%
#Modify value
#By dividing by 1E6
cdf.loc[:, "Value"] = cdf["Value"].div(10**6)
cdf
# Out:
# D:\w\p\m\envs\tensorflow\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#       Year    Value
# 2103  2005  768.700
# 2104  2004  738.900
# 2105  2003  731.200
# 2106  2002  679.800
# 2107  2001  658.400
# 2108  2000  617.900
# 2109  1999  607.700
# 2110  1998  572.600
# 2111  1997  507.500
# 2112  1996  474.100
# 2113  1995  446.422
# 2114  1994  437.165
# 2115  1993  466.534
# 2116  1992  414.748
# 2117  1991  357.360
# 2118  1990  346.411
# 2119  1989  303.890
# 2120  1988  263.400
# 2121  1987  255.100
# 2122  1986  252.600
# 2123  1985  252.400
# 2124  1984  244.800
# 2125  1983  231.600
# 2126  1982  203.800
# 2127  1981  173.100
# 2128  1980  156.700
# 2129  1979  143.900
# ...

# %%
#Vizualizing the histogram
cdf.hist()
plt.show()

# %%
#Export dataframe
cdf.to_csv("fiji_consum_exp.csv", index = False)
